# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylable=["apple", "banana","cherry","dates"]
mycolor=["cyan","black","blue","red"]
plt.subplot(1,2,1)
plt.pie(y, labels=mylable, colors=mycolor)


import matplotlib.pyplot as plt
import numpy
ypoints=numpy.array([3,8,1,10])
plt.subplot(1,2,2)
plt.plot(ypoints)
plt.show()
